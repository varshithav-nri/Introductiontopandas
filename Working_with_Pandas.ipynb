# %% [markdown]
# <a href="https://colab.research.google.com/github/varshithav-nri/Introductiontopandas/blob/main/Working_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
datasetPath = '/content/retail_transactions.csv'

# %%
import pandas as pd

# %%
#	1.	Data Loading & Parsing:
df = pd.read_csv(datasetPath)
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
from datetime import datetime

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
df['TransactionDate']
# Out:
# 0    2024-01-01
# 1    2024-01-02
# 2    2024-01-03
# 3    2024-01-04
# 4    2024-01-05
#         ...
# 95   2024-04-05
# 96   2024-04-06
# 97   2024-04-07
# 98   2024-04-08
# 99   2024-04-09
# Name: TransactionDate, Length: 100, dtype: datetime64[ns]

# %%
#2.	Initial Data Exploration:
df.columns
# Out:
# Index(['TransactionID', 'TransactionDate', 'StoreID', 'CustomerID',
#        'ProductID', 'ProductCategory', 'Quantity', 'Price', 'PaymentType',
#        'Discount'],
#       dtype='object')

# %%
#15rowspending

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    100 non-null    object
#  1   TransactionDate  100 non-null    datetime64[ns]
#  2   StoreID          100 non-null    int64
#  3   CustomerID       100 non-null    int64
#  4   ProductID        100 non-null    int64
#  5   ProductCategory  100 non-null    object
#  6   Quantity         100 non-null    int64
#  7   Price            100 non-null    int64
#  8   PaymentType      100 non-null    object
#  9   Discount         75 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#            TransactionDate     StoreID   CustomerID   ProductID    Quantity  \
# count                  100  100.000000   100.000000  100.000000  100.000000
# mean   2024-02-19 12:00:00  102.730000  1552.520000  554.390000    5.370000
# min    2024-01-01 00:00:00  101.000000  1013.000000  501.000000    1.000000
# 25%    2024-01-25 18:00:00  101.000000  1310.250000  529.750000    3.000000
# 50%    2024-02-19 12:00:00  103.000000  1534.000000  554.000000    5.500000
# 75%    2024-03-15 06:00:00  104.000000  1800.750000  579.500000    8.000000
# max    2024-04-09 00:00:00  105.000000  1983.000000  600.000000   10.000000
# std                    NaN    1.384291   268.295461   28.544098    3.013957
#
#            Price   Discount
# count  100.00000  75.000000
# mean   282.15000   7.733333
# min     50.00000   0.000000
# 25%    165.75000   2.500000
# 50%    280.00000  10.000000
# 75%    415.25000  12.500000
# max    500.00000  15.000000
# std    140.19938   5.652871

# %%
#4. newcolumn= netprice
df['Discountinrupees'] = df['Price'] * df['Discount']//100
df['NetPrice'] = df['Price'] - df['Discountinrupees']
df['TotalSale'] = df['NetPrice'] * df['Quantity']
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  Discountinrupees  \
# 0      Electronics         1    150      Credit      15.0              22.0
# ...

# %%
#	5.	Data Filtering:
filter1= df['TotalSale']>=20
filter1
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: TotalSale, Length: 100, dtype: bool

# %%
df[filter1]
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 7           T008      2024-01-08      101        1806        569
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  Discountinrupees  \
# 0      Electronics         1    150      Credit      15.0              22.0
# ...

# %%
	#6.	Data Type Conversion:
df['PaymentType']=df['PaymentType'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TransactionID     100 non-null    object
#  1   TransactionDate   100 non-null    datetime64[ns]
#  2   StoreID           100 non-null    int64
#  3   CustomerID        100 non-null    int64
#  4   ProductID         100 non-null    int64
#  5   ProductCategory   100 non-null    object
#  6   Quantity          100 non-null    int64
#  7   Price             100 non-null    int64
#  8   PaymentType       100 non-null    category
#  9   Discount          75 non-null     float64
#  10  Discountinrupees  75 non-null     float64
#  11  NetPrice          75 non-null     float64
#  12  TotalSale         75 non-null     float64
# dtypes: category(1), datetime64[ns](1), float64(4), int64(5), object(2)
# memory usage: 9.7+ KB

# %%
df['TotalSale'].sum()
# Out:
# 100193.0

# %%
df['ProductCategory'].mode()
# Out:
# 0    Furniture
# Name: ProductCategory, dtype: object

# %%
df['TotalSale'].mean()
# Out:
# 1335.9066666666668

# %%
filter1= df['TotalSale']> 200
filter1
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4      True
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: TotalSale, Length: 100, dtype: bool

# %%
df[filter1]
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 1           T002      2024-01-02      103        1226        542
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 7           T008      2024-01-08      101        1806        569
# 8           T009      2024-01-09      101        1925        548
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  Discountinrupees  \
# 1             Toys         2    317       Debit      10.0              31.0
# ...

# %%
spending=df.groupby('CustomerID')['TotalSale'].sum()
spending
# Out:
# CustomerID
# 1013       0.0
# 1082       0.0
# 1135     157.0
# 1161    2664.0
# 1169    1480.0
#          ...
# 1950    2259.0
# 1954     981.0
# 1978    1764.0
# 1980       0.0
# 1983       0.0
# Name: TotalSale, Length: 93, dtype: float64

# %%
top3 = spending.sort_values(ascending=False).nlargest(3)
top3
# Out:
# CustomerID
# 1312    3816.0
# 1897    3730.0
# 1245    3553.0
# Name: TotalSale, dtype: float64
