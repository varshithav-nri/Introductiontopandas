# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
dataset=pd.read_csv('/Credit_Card_Applications.csv')

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
dataset.columns
# Out:
# Index(['CustomerID', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9',
#        'A10', 'A11', 'A12', 'A13', 'A14', 'Class'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#          CustomerID          A1          A2          A3          A4  \
# count  6.900000e+02  690.000000  690.000000  690.000000  690.000000
# mean   1.569047e+07    0.678261   31.568203    4.758725    1.766667
# std    7.150647e+04    0.467482   11.853273    4.978163    0.430063
# min    1.556571e+07    0.000000   13.750000    0.000000    1.000000
# 25%    1.563169e+07    0.000000   22.670000    1.000000    2.000000
# 50%    1.569016e+07    1.000000   28.625000    2.750000    2.000000
# 75%    1.575190e+07    1.000000   37.707500    7.207500    2.000000
# max    1.581544e+07    1.000000   80.250000   28.000000    3.000000
#
#                A5          A6          A7          A8          A9        A10  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.00000
# mean     7.372464    4.692754    2.223406    0.523188    0.427536    2.40000
# std      3.683265    1.992316    3.346513    0.499824    0.495080    4.86294
# min      1.000000    1.000000    0.000000    0.000000    0.000000    0.00000
# 25%      4.000000    4.000000    0.165000    0.000000    0.000000    0.00000
# 50%      8.000000    4.000000    1.000000    1.000000    0.000000    0.00000
# 75%     10.000000    5.000000    2.625000    1.000000    1.000000    3.00000
# max     14.000000    9.000000   28.500000    1.000000    1.000000   67.00000
#
#               A11         A12          A13            A14       Class
# count  690.000000  690.000000   690.000000     690.000000  690.000000
# mean     0.457971    1.928986   184.014493    1018.385507    0.444928
# std      0.498592    0.298813   172.159274    5210.102598    0.497318
# min      0.000000    1.000000     0.000000       1.000000    0.000000
# 25%      0.000000    2.000000    80.000000       1.000000    0.000000
# 50%      0.000000    2.000000   160.000000       6.000000    0.000000
# 75%      1.000000    2.000000   272.000000     396.500000    1.000000
# max      1.000000    3.000000  2000.000000  100001.000000    1.000000

# %%
dataset.loc[1,'A2']
# Out:
# 22.67

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
 age.append(random.randint(0,100))
 height.append(random.randint(0,100))
 weight.append(random.randint(0,100))
 speed.append(random.randint(0,100))
idata = {'Age':age,'Height':height,'Weight':weight,'speed':speed}

# %%
idata
# Out:
# {'Age': [17,
#   48,
#   12,
#   75,
#   46,
#   85,
#   7,
#   93,
#   6,
#   17,
#   3,
#   19,
#   93,
#   77,
#   69,
#   59,
#   9,
#   52,
#   88,
#   8,
#   23,
#   45,
#   47,
#   97,
#   0,
#   88,
#   56,
#   69,
#   56,
#   75,
#   29,
#   54,
#   17,
#   9,
#   70,
#   5,
#   40,
#   52,
#   31,
#   55,
#   41,
#   92,
#   61,
#   0,
#   7,
#   97,
#   23,
#   31,
#   79,
#   97,
#   81,
#   42,
#   2,
#   54,
#   74,
#   56,
#   86,
#   50,
#   52,
#   93,
#   75,
#   25,
#   82,
#   77,
#   5,
#   15,
#   4,
#   16,
#   98,
#   5,
#   100,
#   18,
#   1,
#   83,
#   99,
#   14,
#   92,
#   60,
#   55,
#   80,
#   90,
#   60,
#   98,
#   50,
#   21,
#   92,
#   5,
#   59,
#   87,
#   15,
#   91,
#   30,
#   42,
#   80,
#   85,
#   77,
#   18,
#   70,
#   15,
#   76],
#  'Height': [47,
#   82,
#   88,
#   41,
#   78,
#   90,
#   64,
#   61,
#   56,
#   63,
#   7,
#   84,
#   51,
#   75,
#   95,
#   33,
#   39,
#   22,
#   39,
#   8,
#   69,
#   26,
#   93,
#   95,
#   31,
#   18,
#   10,
#   85,
#   94,
#   29,
#   3,
#   2,
#   56,
#   1,
#   21,
#   77,
#   28,
#   97,
#   20,
#   59,
#   85,
#   4,
#   34,
#   65,
#   93,
#   43,
#   53,
#   20,
#   7,
#   19,
#   88,
#   61,
#   48,
#   95,
#   72,
#   98,
#   85,
#   17,
#   79,
#   83,
#   44,
#   3,
#   46,
#   6,
#   15,
#   42,
#   23,
#   65,
#   85,
#   5,
#   28,
#   90,
#   30,
#   45,
#   35,
#   29,
#   93,
#   37,
#   28,
#   53,
#   36,
#   51,
#   28,
#   1,
#   76,
#   14,
#   56,
#   48,
#   43,
#   51,
#   26,
#   18,
#   5,
#   91,
#   15,
#   7,
#   90,
#   12,
#   54,
#   64],
#  'Weight': [26,
#   12,
#   94,
#   60,
#   47,
#   10,
#   50,
#   5,
#   74,
#   39,
#   2,
#   71,
#   77,
#   13,
#   23,
#   78,
#   88,
#   59,
#   83,
#   15,
#   83,
#   86,
#   39,
#   34,
#   4,
#   3,
#   84,
#   9,
#   65,
#   4,
#   91,
#   82,
#   27,
#   20,
#   49,
#   84,
#   50,
#   31,
#   35,
#   54,
#   87,
#   35,
#   6,
#   75,
#   99,
#   66,
#   14,
#   62,
#   1,
#   19,
#   71,
#   27,
#   58,
#   80,
#   17,
#   31,
#   37,
#   0,
#   26,
#   61,
#   92,
#   28,
#   60,
#   76,
#   86,
#   12,
#   78,
#   15,
#   86,
#   95,
#   40,
#   59,
#   69,
#   72,
#   31,
#   49,
#   55,
#   62,
#   50,
#   97,
#   79,
#   83,
#   26,
#   75,
#   7,
#   63,
#   66,
#   84,
#   12,
#   94,
#   40,
#   87,
#   56,
#   32,
#   81,
#   44,
#   73,
#   55,
#   77,
#   12],
#  'speed': [66,
#   48,
#   82,
#   36,
#   8,
#   75,
#   25,
#   48,
#   1,
#   66,
#   71,
#   2,
#   100,
#   36,
#   22,
#   18,
#   34,
#   87,
#   60,
#   94,
#   80,
#   84,
#   93,
#   27,
#   74,
#   57,
#   16,
#   35,
#   93,
#   49,
#   5,
#   66,
#   78,
#   6,
#   71,
#   3,
#   21,
#   99,
#   99,
#   85,
#   13,
#   43,
#   35,
#   32,
#   3,
#   94,
#   20,
#   32,
#   89,
#   72,
#   98,
#   61,
#   12,
#   18,
#   49,
#   82,
#   17,
#   65,
#   78,
#   6,
#   64,
#   98,
#   29,
#   85,
#   79,
#   96,
#   12,
#   36,
#   75,
#   12,
#   95,
#   20,
#   57,
#   9,
#   82,
#   57,
#   2,
#   32,
#   33,
#   31,
#   5,
#   37,
#   99,
#   38,
#   8,
#   13,
#   86,
#   64,
#   82,
#   45,
#   27,
#   76,
#   2,
#   94,
#   38,
#   86,
#   58,
#   15,
#   52,
#   62]}

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  speed
# 0    17      47      26     66
# 1    48      82      12     48
# 2    12      88      94     82
# 3    75      41      60     36
# 4    46      78      47      8
# ..  ...     ...     ...    ...
# 95   77       7      44     86
# 96   18      90      73     58
# 97   70      12      55     15
# 98   15      54      77     52
# 99   76      64      12     62
#
# [100 rows x 4 columns]

# %%
df1.tail(10)
# Out:
#     Age  Height  Weight  speed
# 90   91      26      40     27
# 91   30      18      87     76
# 92   42       5      56      2
# 93   80      91      32     94
# 94   85      15      81     38
# 95   77       7      44     86
# 96   18      90      73     58
# 97   70      12      55     15
# 98   15      54      77     52
# 99   76      64      12     62

# %%
df1.describe()
# Out:
#               Age      Height      Weight       speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    50.840000   47.740000   50.900000   50.300000
# std     32.257086   30.067473   29.366545   31.579785
# min      0.000000    1.000000    0.000000    1.000000
# 25%     17.750000   21.750000   26.000000   20.750000
# 50%     54.000000   45.500000   55.000000   49.000000
# 75%     80.000000   76.250000   77.250000   79.250000
# max    100.000000   98.000000   99.000000  100.000000

# %%
df1['Age']
# Out:
# 0     17
# 1     48
# 2     12
# 3     75
# 4     46
#       ..
# 95    77
# 96    18
# 97    70
# 98    15
# 99    76
# Name: Age, Length: 100, dtype: int64

# %%
df1.loc[[0,3],['Age','Weight']]
# Out:
#    Age  Weight
# 0   17      26
# 3   75      60

# %%
df2 = df1[['Age','Weight']]

# %%
df2
# Out:
#     Age  Weight
# 0    17      26
# 1    48      12
# 2    12      94
# 3    75      60
# 4    46      47
# ..  ...     ...
# 95   77      44
# 96   18      73
# 97   70      55
# 98   15      77
# 99   76      12
#
# [100 rows x 2 columns]

# %%
df2.sort_index(ascending=False)
# Out:
#     Age  Weight
# 99   76      12
# 98   15      77
# 97   70      55
# 96   18      73
# 95   77      44
# ..  ...     ...
# 4    46      47
# 3    75      60
# 2    12      94
# 1    48      12
# 0    17      26
#
# [100 rows x 2 columns]

# %%
#slicing method
df1[0::2]
# Out:
#     Age  Height  Weight  speed
# 0    17      47      26     66
# 2    12      88      94     82
# 4    46      78      47      8
# 6     7      64      50     25
# 8     6      56      74      1
# 10    3       7       2     71
# 12   93      51      77    100
# 14   69      95      23     22
# 16    9      39      88     34
# 18   88      39      83     60
# 20   23      69      83     80
# 22   47      93      39     93
# 24    0      31       4     74
# 26   56      10      84     16
# 28   56      94      65     93
# 30   29       3      91      5
# 32   17      56      27     78
# 34   70      21      49     71
# 36   40      28      50     21
# 38   31      20      35     99
# 40   41      85      87     13
# 42   61      34       6     35
# 44    7      93      99      3
# 46   23      53      14     20
# 48   79       7       1     89
# 50   81      88      71     98
# 52    2      48      58     12
# 54   74      72      17     49
# 56   86      85      37     17
# 58   52      79      26     78
# 60   75      44      92     64
# 62   82      46      60     29
# 64    5      15      86     79
# 66    4      23      78     12
# 68   98      85      86     75
# 70  100      28      40     95
# 72    1      30      69     57
# 74   99      35      31     82
# 76   92      93      55      2
# 78   55      28      50     33
# 80   90      36      79      5
# 82   98      28      26     99
# 84   21      76       7      8
# 86    5      56      66     86
# 88   87      43      12     82
# 90   91      26      40     27
# 92   42       5      56      2
# 94   85      15      81     38
# 96   18      90      73     58
# 98   15      54      77     52

# %%
df1[0::2].describe()
# Out:
#               Age     Height     Weight       speed
# count   50.000000  50.000000  50.000000   50.000000
# mean    47.760000  49.780000  53.420000   49.960000
# std     34.591824  28.536615  28.961685   33.688828
# min      0.000000   3.000000   1.000000    1.000000
# 25%     15.500000  28.000000  28.000000   17.750000
# 50%     46.500000  46.500000  55.500000   54.500000
# 75%     81.750000  77.500000  78.750000   79.750000
# max    100.000000  95.000000  99.000000  100.000000

# %%
#filter- with conditional operators
filter1 = df1['Weight'] > 50

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  speed
# 2    12      88      94     82
# 3    75      41      60     36
# 8     6      56      74      1
# 11   19      84      71      2
# 12   93      51      77    100
# 15   59      33      78     18
# 16    9      39      88     34
# 17   52      22      59     87
# 18   88      39      83     60
# 20   23      69      83     80
# 21   45      26      86     84
# 26   56      10      84     16
# 28   56      94      65     93
# 30   29       3      91      5
# 31   54       2      82     66
# 35    5      77      84      3
# 39   55      59      54     85
# 40   41      85      87     13
# 43    0      65      75     32
# 44    7      93      99      3
# 45   97      43      66     94
# 47   31      20      62     32
# 50   81      88      71     98
# 52    2      48      58     12
# 53   54      95      80     18
# 59   93      83      61      6
# 60   75      44      92     64
# 62   82      46      60     29
# 63   77       6      76     85
# 64    5      15      86     79
# 66    4      23      78     12
# 68   98      85      86     75
# 69    5       5      95     12
# 71   18      90      59     20
# 72    1      30      69     57
# 73   83      45      72      9
# 76   92      93      55      2
# 77   60      37      62     32
# 79   80      53      97     31
# 80   90      36      79      5
# 81   60      51      83     37
# 83   50       1      75     38
# 85   92      14      63     13
# 86    5      56      66     86
# 87   59      48      84     64
# 89   15      51      94     45
# 91   30      18      87     76
# 92   42       5      56      2
# 94   85      15      81     38
# 96   18      90      73     58
# 97   70      12      55     15
# 98   15      54      77     52

# %%
filter2 = df1['Age'] > 40

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  Weight  speed
# 3    75      41      60     36
# 12   93      51      77    100
# 15   59      33      78     18
# 17   52      22      59     87
# 18   88      39      83     60
# 21   45      26      86     84
# 26   56      10      84     16
# 28   56      94      65     93
# 31   54       2      82     66
# 39   55      59      54     85
# 40   41      85      87     13
# 45   97      43      66     94
# 50   81      88      71     98
# 53   54      95      80     18
# 59   93      83      61      6
# 60   75      44      92     64
# 62   82      46      60     29
# 63   77       6      76     85
# 68   98      85      86     75
# 73   83      45      72      9
# 76   92      93      55      2
# 77   60      37      62     32
# 79   80      53      97     31
# 80   90      36      79      5
# 81   60      51      83     37
# 83   50       1      75     38
# 85   92      14      63     13
# 87   59      48      84     64
# 92   42       5      56      2
# 94   85      15      81     38
# 97   70      12      55     15

# %%
df1.loc[filter1 | filter2]
# Out:
#     Age  Height  Weight  speed
# 1    48      82      12     48
# 2    12      88      94     82
# 3    75      41      60     36
# 4    46      78      47      8
# 5    85      90      10     75
# ..  ...     ...     ...    ...
# 95   77       7      44     86
# 96   18      90      73     58
# 97   70      12      55     15
# 98   15      54      77     52
# 99   76      64      12     62
#
# [84 rows x 4 columns]
